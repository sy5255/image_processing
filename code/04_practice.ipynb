# %% [markdown]
# # Phase 4 — 실습 문제
#
# 각 문제의 `# TODO` 를 채우고 실행하십시오. `assert` 가 통과하면 `통과` 가 출력됩니다.

# %% [markdown]
# ## 0. 그래프 한글 폰트 설정
#
# 그래프 제목·축 라벨에 한글을 쓸 때 깨지지 않도록, 설치된 한글 폰트를 찾아 적용합니다. (없으면 라벨은 영어로 표기)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
for _n in ['Malgun Gothic','NanumGothic','AppleGothic','Noto Sans CJK KR','Noto Sans KR']:
    if _n in {f.name for f in fm.fontManager.ttflist}:
        plt.rcParams['font.family'] = _n; print('한글 폰트 적용:', _n); break
else:
    print('한글 폰트를 찾지 못했습니다 — 라벨은 영어로 표기합니다.')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 문제 1. 좌표로 픽셀 읽기
# 아래 배열 `g` 에서 **행 2, 열 4** 의 값을 `v` 에 담으십시오. (좌표 순서에 주의)

# %%
import numpy as np
g = np.arange(30).reshape(5, 6)
v = # TODO

assert v == 16
print('통과')

# %% [markdown]
# ### 문제 2. bit depth 범위
# uint16 의 최댓값을 `mx` 에 담으십시오. (힌트: np.iinfo)

# %%
mx = # TODO

assert mx == 65535
print('통과')

# %% [markdown]
# ### 문제 3. 픽셀 → nm 환산 함수
# 픽셀 길이와 scale 을 입력받아 nm 길이를 반환하는 함수 `px_to_nm` 를 정의하십시오.

# %%
# TODO: def px_to_nm(px, scale): ...

assert px_to_nm(80, 0.25) == 20.0
assert px_to_nm(100, 0.5) == 50.0
print('통과')

# %% [markdown]
# ### 문제 4. 면적 환산
# 마스크 픽셀 수 `area_px = 1200` 과 `scale = 0.2` (nm/pixel) 로 실제 면적(nm²)을 `area_nm2` 에 담으십시오.
# (힌트: 면적은 scale 을 두 번 곱합니다)

# %%
area_px = 1200
scale = 0.2
area_nm2 = # TODO

assert abs(area_nm2 - 48.0) < 1e-9
print('통과')

# %% [markdown]
# ### 문제 5. 두께 측정값 환산 (반복)
# 픽셀 두께 목록 `pxs = [80, 84, 76]` 을 scale `0.25` 로 환산해 nm 목록 `nms` 로 만드십시오.

# %%
pxs = [80, 84, 76]
scale = 0.25
nms = []

# TODO: for 문으로 환산

assert nms == [20.0, 21.0, 19.0]
print('통과')

# %% [markdown]
# ---
# 이상으로 Phase 4 실습을 마칩니다. 다음 단계에서는 이미지 처리 기본기(전처리·이진화·마스크)를 다룹니다.

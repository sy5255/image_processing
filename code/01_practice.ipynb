# %% [markdown]
# # Phase 1 — 실습 문제
#
# 각 문제의 `# TODO` 부분을 작성한 뒤 셀을 실행하십시오. 셀 하단의 `assert` 가 오류 없이 통과하면 `통과` 가 출력됩니다.

# %% [markdown]
# ### 문제 1. 변수와 자료형
# 픽셀당 nm 값 `scale` 을 실수 `0.2`, 측정 개수 `count` 를 정수 `8` 로 정의하십시오.

# %%
# TODO: scale 과 count 를 정의
scale = 
count = 

assert isinstance(scale, float) and scale == 0.2
assert isinstance(count, int) and count == 8
print('통과')

# %% [markdown]
# ### 문제 2. list 정의 및 요소 참조
# 측정값 리스트 `[12.1, 11.8, 12.4, 13.0]` 을 `w` 에 정의하고, 마지막 값을 `last` 에 참조하십시오.

# %%
w = # TODO
last = # TODO  (인덱싱 사용)

assert w[1] == 11.8
assert last == 13.0
print('통과')

# %% [markdown]
# ### 문제 3. 값 추가 · 수정 · 제거 (list)
# 리스트 `vals = [10.0, 11.0]` 에 대해 다음을 수행하십시오.
# 1) `12.0` 을 끝에 추가  2) 첫 번째 값을 `9.0` 으로 수정  3) 값 `11.0` 을 제거

# %%
vals = [10.0, 11.0]

# TODO: 1) append  2) 인덱스 수정  3) remove

assert vals == [9.0, 12.0]
print('통과')

# %% [markdown]
# ### 문제 4. 값 추가 · 수정 · 제거 (dict)
# 딕셔너리 `m = {'name': 'A'}` 에 대해 키 `'thk'` 에 `12.4` 를 추가하고, `'name'` 키를 제거하십시오.

# %%
m = {'name': 'A'}

# TODO: 'thk' 추가, 'name' 제거

assert m == {'thk': 12.4}
print('통과')

# %% [markdown]
# ### 문제 5. 슬라이싱
# 리스트 `w = [12.1, 11.8, 12.4, 13.0]` 에서 가운데 두 값(`11.8, 12.4`)을 `mid` 에 담으십시오.

# %%
w = [12.1, 11.8, 12.4, 13.0]
mid = # TODO  (슬라이싱 사용)

assert mid == [11.8, 12.4]
print('통과')

# %% [markdown]
# ### 문제 6. 반복문과 조건 (continue)
# 리스트 `data = [12.1, None, 12.4, None, 13.0]` 에서 `None` 을 제외한 유효한 값만 `good` 에 모으십시오.

# %%
data = [12.1, None, 12.4, None, 13.0]
good = []

# TODO: for + if + continue 사용

assert good == [12.1, 12.4, 13.0]
print('통과')

# %% [markdown]
# ### 문제 7. 함수 정의
# 리스트를 입력받아 평균을 반환하는 함수 `average` 를 정의하십시오. (라이브러리 미사용, for 로 구현)

# %%
# TODO: def average(values): ...

assert average([10, 20, 30]) == 20.0
assert round(average([12.1, 11.8, 12.4, 13.0]), 3) == 12.325
print('통과')

# %% [markdown]
# ---
# 이상으로 Phase 1 실습을 마칩니다.

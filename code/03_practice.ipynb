# %% [markdown]
# # Phase 3 — 실습 문제
#
# 각 문제의 `# TODO` 를 채우고 실행하십시오. `assert` 가 통과하면 `통과` 가 출력됩니다.

# %% [markdown]
# ## 0. 그래프 한글 폰트 설정
#
# 그래프 제목·축 라벨에 한글을 쓸 때 깨지지 않도록, 설치된 한글 폰트를 찾아 적용합니다. (없으면 라벨은 영어로 표기)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
for _n in ['Malgun Gothic','NanumGothic','AppleGothic','Noto Sans CJK KR','Noto Sans KR']:
    if _n in {f.name for f in fm.fontManager.ttflist}:
        plt.rcParams['font.family'] = _n; print('한글 폰트 적용:', _n); break
else:
    print('한글 폰트를 찾지 못했습니다 — 라벨은 영어로 표기합니다.')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 문제 1. 배열 만들기와 shape
# 0부터 11까지의 정수를 가진 3행 4열 배열 `arr` 를 만드십시오. (힌트: np.arange, reshape)

# %%
arr = # TODO

assert arr.shape == (3, 4)
assert arr[0, 0] == 0 and arr[2, 3] == 11
print('통과')

# %% [markdown]
# ### 문제 2. ROI 슬라이싱
# 아래 6x6 배열 `g` 에서 가운데 2x2 영역(행 2~3, 열 2~3)을 `roi` 로 잘라내십시오.

# %%
g = np.arange(36).reshape(6, 6)
roi = # TODO

assert roi.shape == (2, 2)
assert roi.tolist() == [[14, 15], [20, 21]]
print('통과')

# %% [markdown]
# ### 문제 3. ROI 값 바꾸기
# `g2` 의 첫 2개 행 전체(행 0~1)를 모두 0으로 바꾸십시오.

# %%
g2 = np.arange(36).reshape(6, 6)

# TODO: 슬라이싱으로 행 0~1 을 0으로

assert g2[0].sum() == 0 and g2[1].sum() == 0
assert g2[2].sum() != 0
print('통과')

# %% [markdown]
# ### 문제 4. 불리언 마스킹 — 개수 세기
# 배열 `img` 에서 밝기값이 100 보다 큰 픽셀의 개수를 `cnt` 에 담으십시오.

# %%
img = np.array([[ 10, 160,  80],
                [200,  50, 255],
                [120, 240,  30]], dtype=np.uint8)
cnt = # TODO  (np.count_nonzero 사용)

assert cnt == 5
print('통과')

# %% [markdown]
# ### 문제 5. 마스킹으로 값 바꾸기
# 위 `img` 에서 밝기값이 100 이하인 픽셀을 모두 0으로 바꾼 결과를 `out` 에 담으십시오. (원본 img 는 유지)

# %%
out = img.copy()

# TODO: 마스크로 100 이하 픽셀을 0으로

assert out.tolist() == [[0, 160, 0], [200, 0, 255], [120, 240, 0]]
print('통과')

# %% [markdown]
# ### 문제 6. axis 평균
# 배열 `a` 의 열별 평균(각 열의 평균)을 `col_mean` 에 담으십시오.

# %%
a = np.array([[2, 4, 6],
              [4, 6, 8]], dtype=float)
col_mean = # TODO  (axis 지정)

assert col_mean.tolist() == [3.0, 5.0, 7.0]
print('통과')

# %% [markdown]
# ---
# 이상으로 Phase 3 실습을 마칩니다.
